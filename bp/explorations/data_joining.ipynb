# %%
import pandas as pd

# %%
foch_path = '/Users/jk1/temp/bp_dci/foch/bp_timebin_2h/bp_timebins_2h_normalised_metrics_normalised.csv'
kssg_path = '/Users/jk1/temp/bp_dci/kssg/bp_timebin_2h/bp_timebins_2h_nor_filtered_normalised_metrics_normalised.csv'

# %%
foch_df = pd.read_csv(foch_path)
kssg_df = pd.read_csv(kssg_path)

# %%
foch_df.head()

# %%
kssg_df.head()

# %%
foch_df.columns

# %%
kssg_df.columns

# %%
# rename PatientId to pNr in foch_df 
foch_df.rename(columns={'PatientID': 'pNr'}, inplace=True)

# %%
# concatenate data
df = pd.concat([foch_df, kssg_df], ignore_index=True)

# %%
df.shape, foch_df.shape, kssg_df.shape
