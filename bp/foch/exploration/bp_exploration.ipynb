# %%
import pandas as pd
import seaborn as sns

# %%
registry_path = '/Users/jk1/Library/CloudStorage/OneDrive-unige.ch/icu_research/dci_sah/data/foch_data/HSA_dci_manual_extraction.xlsx'
pa_path = '/Users/jk1/Library/CloudStorage/OneDrive-unige.ch/icu_research/dci_sah/data/foch_data/extracted_vitals/klug-PA.csv'
pni_path = '/Users/jk1/Library/CloudStorage/OneDrive-unige.ch/icu_research/dci_sah/data/foch_data/extracted_vitals/klug-PNI.csv'

# %%
registry_df = pd.read_excel(registry_path)

# %%
pa_df = pd.read_csv(pa_path)
pni_df = pd.read_csv(pni_path)

# %%
registry_df

# %%
pa_df

# %%
pni_df.head()

# %%
pni_df.VariableID.value_counts()

# %%
# violinplot from value and status as x axis
ax = sns.violinplot(x='VariableID', y='Value', data=pa_df, hue='VariableID', legend=False)
ax.set_ylim(0, 300)

# %%
ax = sns.violinplot(x='VariableID', y='Value', data=pni_df, hue='VariableID', legend=False)
ax.set_ylim(0, 300)
