# %%
from utils.utils import load_encrypted_xlsx
import pandas
import getpass

# %%
registry_pdms_correspondence_path = '/Users/jk1/Library/CloudStorage/OneDrive-unige.ch/icu_research/dci_sah/data/pdms_data/registry_pdms_correspondence.csv'
outcome_df_path = '/Users/jk1/Library/CloudStorage/OneDrive-unige.ch/icu_research/dci_sah/data/sos_sah_data/follow_up/aSAH_DATA_2009_2024_18122024.xlsx'

# %%
password_outcome_df = getpass.getpass()

# %%
reg_pdms_df = pandas.read_csv(registry_pdms_correspondence_path)

# %%
outcome_df = load_encrypted_xlsx(outcome_df_path, password=password_outcome_df)

# %%
reg_pdms_df.head()

# %%
outcome_df.head()

# %%
# merge on SOS-CENTER-YEAR-NO. to get mRS_FU_1y from outcome_df
merged_df = pandas.merge(reg_pdms_df, outcome_df[['SOS-CENTER-YEAR-NO.', 'mRS_FU_1y']], on='SOS-CENTER-YEAR-NO.', how='left')

# %%
merged_df.head()

# %%
# filter out rows with pNr NaN
merged_df = merged_df[merged_df['pNr'].notna()]

# %%
# find number of nan in mRS_FU_1y as fraction of total
merged_df['mRS_FU_1y'].isna().sum() / len(merged_df)
